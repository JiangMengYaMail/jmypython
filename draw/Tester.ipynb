# %%
from draw2d import *
from draw3d import *
import vector_utils

# points2d = [(1,1), (6,60), (6,20), (2,1)]
# points3d = [(1,1,1), (6,60,60), (6,20,20), (2,1,1)]
# draw3d()
# draw3d(Points3D((2,2,2), (1,-2,-2)), Arrow3D((2,2,2)), Arrow3D((1,-2,-2)))

# %%
a = (1,2,3)
b = (4,5,6)
print(vector_utils.add(a, b))
# Out:
# ...
# [5, 7, 9]
# (5, 7, 9)
