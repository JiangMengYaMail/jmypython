# %%
from draw2d import *
import sys
sys.path.append('draw_vector/')
from vector_draw import *
points = [(1,1), (6,60), (6,20), (2,1)]

# %%
draw2d(Polygon2D(*points, fill='r'), grid=(1,10), raw_aspect_ratio=False)

# %%
draw2d(Points2D(*points, color='g'), grid=(1, 10), raw_aspect_ratio=False)

# %%
draw2d(Arrow2D(tip=points[1], tail=points[0], color='g'), grid=(1, 10), raw_aspect_ratio=False)

# %%
draw2d(Segment2D(points[1], points[0]), grid=(1, 10), raw_aspect_ratio=False)
